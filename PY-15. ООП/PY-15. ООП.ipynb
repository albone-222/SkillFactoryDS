# %%
class DepartmentReport():
    def add_revenue(self, amount):
        """
        Метод для добавления выручки отдела в список revenues.
        Если атрибута revenues ещё не существует, метод должен создавать пустой список перед добавлением выручки.
        """
        if not hasattr(self, 'revenues'):
            self.revenues = []
        
        self.revenues.append(amount)
    
    def average_revenue(self):
        """
        Метод возвращает среднюю выручку по отделам.
        """
        return sum(self.revenues)/len(self.revenues)

report = DepartmentReport()
report.add_revenue(1_000_000)
report.add_revenue(400_000)
print(report.revenues)
print(report.average_revenue())
# Out:
# [1000000, 400000]
# 700000.0

# %%
class DepartmentReport():

    def __init__(self,company):
        """
        Метод инициализации класса. 
        Создаёт атрибуты revenues и company
        """
        self.revenues = []
        self.company = company
    
    def add_revenue(self, amount):
        """
        Метод для добавления выручки отдела в список revenues.
        Если атрибута revenues ещё не существует, метод должен создавать пустой список перед добавлением выручки.
        """
        self.revenues.append(amount)
    
    def average_revenue(self):
        """
        Вычисляет average_revenue — среднюю выручку по отделам — округляя до целого.
        Метод возвращает строку в формате:
        'Average department revenue for <company>: <average_revenue>'
        """
        average= round(sum(self.revenues)/len(self.revenues), 0)
        return f'Average department revenue for {self.company}: {average}'

report = DepartmentReport("Danon2")
report.add_revenue(300)
report.add_revenue(15)

print(report.average_revenue())
# Out:
# Average department revenue for Danon2: 158.0

# %%
class User():
    def __init__(self, email, password, balance):
        self.email = email
        self.password = password
        self.balance = balance
    
    def login(self, email, password):
        if email==self.email and password==self.password:
            return True
        return False
        
    def update_balance(self, amount):
        self.balance += amount

user = User("gosha@roskino.org", "qwerty", 20_000)
user.login("gosha@roskino.org", "qwerty")
user.update_balance(200)
user.update_balance(-500)
print(user.balance)
# Out:
# 19700

# %%
class IntDataFrame():
    def __init__(self, data):
        self.data = [int(x) for x in data]
        
    def count(self):
        return len([x for x in self.data if x!=0])
    
    def unique(self):
        return len(set(self.data))
    
df = IntDataFrame([4.7, 4, 3, 0, 2.4, 0.3, 4])
df.unique()
# Out:
# 4

# %%
class OwnLogger():
    def __init__(self):
        self.messages = {'info':[], 'warning':[], 'error':[]}
        self.last_message = None
    
    def log(self, message, level):
        if level in self.messages.keys():
            self.messages[level].append(message)
            self.last_message = message
        else: 
            print('Wrong level')
    
    def show_last(self, level='all'):
        if level == 'all':
            return self.last_message
        elif level in self.messages.keys():
            if len(self.messages[level]):
                return self.messages[level][-1]
            return None   
        else: 
            print('Wrong level')

logger = OwnLogger()
logger.log("System started", "info")
logger.show_last("error")

# %%
logger.log("Connection instable", "warning")
logger.log("Connection lost", "error")
logger.show_last()
# Out:
# 'Connection lost'

# %%
logger.show_last("info")
# Out:
# 'System started'

# %%
import os

def walk_desc(path=None):
    start_path = path if path is not None else os.getcwd()

    for root, dirs, files in os.walk(start_path):
        print("Текущая директория", root)
        print("---")

        if dirs:
            print("Список папок", dirs)
        else:
            print("Папок нет")
        print("---")

        if files:
            print("Список файлов", files)
        else:
            print("Файлов нет")
        print("---")

        if files and dirs:
            print("Все пути:")
        for f in files:
            print("Файл ", os.path.join(root, f))
        for d in dirs:
            print("Папка ", os.path.join(root, d))
        print("===")

walk_desc('g:\Data Sciense')
# Out:
# Текущая директория g:\Data Sciense
# ---
# Список папок ['IDE SF', 'SF практика', 'temp']
# ---
# Список файлов ['DSPR_Блок_0_Модуль_5.1._Введение_в_функции_в_Python.pdf', 'DSPR_Блок_0_Модуль_5.2._Продвинутое_использование_функций_в_Python.pdf', 'DSPR_Блок_1_Модуль_1._Основы_Python.pdf', 'DSPR_Блок_1_Модуль_10._Введение_в_Pandas.pdf', 'DSPR_Блок_1_Модуль_11._Базовые_приёмы_работы_с_данными_в_Pandas.pdf', 'DSPR_Блок_1_Модуль_12._Продвинутые_методы_работы_с_данными_в_Pandas.pdf', 'DSPR_Блок_1_Модуль_13._Визуализация_данных.pdf', 'DSPR_Блок_1_Модуль_2._Погружение_в_типы_данных.pdf', 'DSPR_Блок_1_Модуль_3._Условные_операторы.pdf', 'DSPR_Блок_1_Модуль_4._Циклы.pdf', 'DSPR_Блок_1_Модуль_9._Библиотека_NumPy.pdf', 'DST_Блок_2_Модуль_14._Очистка_данных.pdf', 'Module-INTRO-2-DST-3.pdf', 'Pandas_info.pdf', 'Python_Vizualizatsia_dannykh_Matplotlib_Seaborn_Mayavi_2020.pdf', 'Абдрахманов_М_И_Pandas_Работа_с_данными_2020.pdf']
# ---
# Все пути:
# Файл  g:\Data Sciense\DSPR_Блок_0_Модуль_5.1._Введение_в_функции_в_Python.pdf
# Файл  g:\Data Sciense\DSPR_Блок_0_Модуль_5.2._Продвинутое_использование_функций_в_Python.pdf
# Файл  g:\Data Sciense\DSPR_Блок_1_Модуль_1._Основы_Python.pdf
# Файл  g:\Data Sciense\DSPR_Блок_1_Модуль_10._Введение_в_Pandas.pdf
# Файл  g:\Data Sciense\DSPR_Блок_1_Модуль_11._Базовые_приёмы_работы_с_данными_в_Pandas.pdf
# Файл  g:\Data Sciense\DSPR_Блок_1_Модуль_12._Продвинутые_методы_работы_с_данными_в_Pandas.pdf
# Файл  g:\Data Sciense\DSPR_Блок_1_Модуль_13._Визуализация_данных.pdf
# Файл  g:\Data Sciense\DSPR_Блок_1_Модуль_2._Погружение_в_типы_данных.pdf
# Файл  g:\Data Sciense\DSPR_Блок_1_Модуль_3._Условные_операторы.pdf
# Файл  g:\Data Sciense\DSPR_Блок_1_Модуль_4._Циклы.pdf
# Файл  g:\Data Sciense\DSPR_Блок_1_Модуль_9._Библиотека_NumPy.pdf
# Файл  g:\Data Sciense\DST_Блок_2_Модуль_14._Очистка_данных.pdf
# Файл  g:\Data Sciense\Module-INTRO-2-DST-3.pdf
# Файл  g:\Data Sciense\Pandas_info.pdf
# Файл  g:\Data Sciense\Python_Vizualizatsia_dannykh_Matplotlib_Seaborn_Mayavi_2020.pdf
# Файл  g:\Data Sciense\Абдрахманов_М_И_Pandas_Работа_с_данными_2020.pdf
# Папка  g:\Data Sciense\IDE SF
# Папка  g:\Data Sciense\SF практика
# Папка  g:\Data Sciense\temp
# ===
# Текущая директория g:\Data Sciense\IDE SF
# ---
# Список папок ['.git', 'project_0']
# ---
# Список файлов ['.gitignore', 'README.md', 'requirements.txt']
# ---
# Все пути:
# Файл  g:\Data Sciense\IDE SF\.gitignore
# Файл  g:\Data Sciense\IDE SF\README.md
# Файл  g:\Data Sciense\IDE SF\requirements.txt
# Папка  g:\Data Sciense\IDE SF\.git
# Папка  g:\Data Sciense\IDE SF\project_0
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git
# ---
# Список папок ['hooks', 'info', 'logs', 'objects', 'refs']
# ---
# Список файлов ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'ORIG_HEAD', 'packed-refs']
# ---
# Все пути:
# Файл  g:\Data Sciense\IDE SF\.git\COMMIT_EDITMSG
# Файл  g:\Data Sciense\IDE SF\.git\config
# Файл  g:\Data Sciense\IDE SF\.git\description
# Файл  g:\Data Sciense\IDE SF\.git\FETCH_HEAD
# Файл  g:\Data Sciense\IDE SF\.git\HEAD
# Файл  g:\Data Sciense\IDE SF\.git\index
# Файл  g:\Data Sciense\IDE SF\.git\ORIG_HEAD
# Файл  g:\Data Sciense\IDE SF\.git\packed-refs
# Папка  g:\Data Sciense\IDE SF\.git\hooks
# Папка  g:\Data Sciense\IDE SF\.git\info
# Папка  g:\Data Sciense\IDE SF\.git\logs
# Папка  g:\Data Sciense\IDE SF\.git\objects
# Папка  g:\Data Sciense\IDE SF\.git\refs
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\hooks
# ---
# Папок нет
# ---
# Список файлов ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'update.sample']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\hooks\applypatch-msg.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\commit-msg.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\fsmonitor-watchman.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\post-update.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\pre-applypatch.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\pre-commit.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\pre-merge-commit.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\pre-push.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\pre-rebase.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\pre-receive.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\prepare-commit-msg.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\push-to-checkout.sample
# Файл  g:\Data Sciense\IDE SF\.git\hooks\update.sample
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\info
# ---
# Папок нет
# ---
# Список файлов ['exclude']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\info\exclude
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\logs
# ---
# Список папок ['refs']
# ---
# Список файлов ['HEAD']
# ---
# Все пути:
# Файл  g:\Data Sciense\IDE SF\.git\logs\HEAD
# Папка  g:\Data Sciense\IDE SF\.git\logs\refs
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\logs\refs
# ---
# Список папок ['heads', 'remotes']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\IDE SF\.git\logs\refs\heads
# Папка  g:\Data Sciense\IDE SF\.git\logs\refs\remotes
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\logs\refs\heads
# ---
# Папок нет
# ---
# Список файлов ['main', 'master']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\logs\refs\heads\main
# Файл  g:\Data Sciense\IDE SF\.git\logs\refs\heads\master
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\logs\refs\remotes
# ---
# Список папок ['SF_DS_homework']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\IDE SF\.git\logs\refs\remotes\SF_DS_homework
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\logs\refs\remotes\SF_DS_homework
# ---
# Папок нет
# ---
# Список файлов ['main', 'master']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\logs\refs\remotes\SF_DS_homework\main
# Файл  g:\Data Sciense\IDE SF\.git\logs\refs\remotes\SF_DS_homework\master
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects
# ---
# Список папок ['06', '08', '0e', '1a', '1b', '1e', '25', '29', '2b', '4f', '52', '5a', '5c', '61', '6e', '70', '79', '7a', '7b', '7e', '80', '92', '9d', 'a1', 'a6', 'b6', 'b8', 'be', 'bf', 'c0', 'c1', 'c3', 'ca', 'd1', 'd6', 'd8', 'da', 'dd', 'e8', 'ec', 'ed', 'f0', 'f1', 'f2', 'f5', 'f7', 'fa', 'fb', 'info', 'pack']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\IDE SF\.git\objects\06
# Папка  g:\Data Sciense\IDE SF\.git\objects\08
# Папка  g:\Data Sciense\IDE SF\.git\objects\0e
# Папка  g:\Data Sciense\IDE SF\.git\objects\1a
# Папка  g:\Data Sciense\IDE SF\.git\objects\1b
# Папка  g:\Data Sciense\IDE SF\.git\objects\1e
# Папка  g:\Data Sciense\IDE SF\.git\objects\25
# Папка  g:\Data Sciense\IDE SF\.git\objects\29
# Папка  g:\Data Sciense\IDE SF\.git\objects\2b
# Папка  g:\Data Sciense\IDE SF\.git\objects\4f
# Папка  g:\Data Sciense\IDE SF\.git\objects\52
# Папка  g:\Data Sciense\IDE SF\.git\objects\5a
# Папка  g:\Data Sciense\IDE SF\.git\objects\5c
# Папка  g:\Data Sciense\IDE SF\.git\objects\61
# Папка  g:\Data Sciense\IDE SF\.git\objects\6e
# Папка  g:\Data Sciense\IDE SF\.git\objects\70
# Папка  g:\Data Sciense\IDE SF\.git\objects\79
# Папка  g:\Data Sciense\IDE SF\.git\objects\7a
# Папка  g:\Data Sciense\IDE SF\.git\objects\7b
# Папка  g:\Data Sciense\IDE SF\.git\objects\7e
# Папка  g:\Data Sciense\IDE SF\.git\objects\80
# Папка  g:\Data Sciense\IDE SF\.git\objects\92
# Папка  g:\Data Sciense\IDE SF\.git\objects\9d
# Папка  g:\Data Sciense\IDE SF\.git\objects\a1
# Папка  g:\Data Sciense\IDE SF\.git\objects\a6
# Папка  g:\Data Sciense\IDE SF\.git\objects\b6
# Папка  g:\Data Sciense\IDE SF\.git\objects\b8
# Папка  g:\Data Sciense\IDE SF\.git\objects\be
# Папка  g:\Data Sciense\IDE SF\.git\objects\bf
# Папка  g:\Data Sciense\IDE SF\.git\objects\c0
# Папка  g:\Data Sciense\IDE SF\.git\objects\c1
# Папка  g:\Data Sciense\IDE SF\.git\objects\c3
# Папка  g:\Data Sciense\IDE SF\.git\objects\ca
# Папка  g:\Data Sciense\IDE SF\.git\objects\d1
# Папка  g:\Data Sciense\IDE SF\.git\objects\d6
# Папка  g:\Data Sciense\IDE SF\.git\objects\d8
# Папка  g:\Data Sciense\IDE SF\.git\objects\da
# Папка  g:\Data Sciense\IDE SF\.git\objects\dd
# Папка  g:\Data Sciense\IDE SF\.git\objects\e8
# Папка  g:\Data Sciense\IDE SF\.git\objects\ec
# Папка  g:\Data Sciense\IDE SF\.git\objects\ed
# Папка  g:\Data Sciense\IDE SF\.git\objects\f0
# Папка  g:\Data Sciense\IDE SF\.git\objects\f1
# Папка  g:\Data Sciense\IDE SF\.git\objects\f2
# Папка  g:\Data Sciense\IDE SF\.git\objects\f5
# Папка  g:\Data Sciense\IDE SF\.git\objects\f7
# Папка  g:\Data Sciense\IDE SF\.git\objects\fa
# Папка  g:\Data Sciense\IDE SF\.git\objects\fb
# Папка  g:\Data Sciense\IDE SF\.git\objects\info
# Папка  g:\Data Sciense\IDE SF\.git\objects\pack
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\06
# ---
# Папок нет
# ---
# Список файлов ['caa40cedaac5f4a3d72eb1719a3f2f4484f4fa']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\06\caa40cedaac5f4a3d72eb1719a3f2f4484f4fa
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\08
# ---
# Папок нет
# ---
# Список файлов ['b472aa95f1b0eb4e7170ecd5ea722f7e386220']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\08\b472aa95f1b0eb4e7170ecd5ea722f7e386220
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\0e
# ---
# Папок нет
# ---
# Список файлов ['41fab43d8ad1b7db02f179b3c476bed3095700', 'e2b54b94c17ab2dc848104c7d118cf50d522ed']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\0e\41fab43d8ad1b7db02f179b3c476bed3095700
# Файл  g:\Data Sciense\IDE SF\.git\objects\0e\e2b54b94c17ab2dc848104c7d118cf50d522ed
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\1a
# ---
# Папок нет
# ---
# Список файлов ['0a88f24f7f21f1cd5ad0ca3c4702b2159cf76f']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\1a\0a88f24f7f21f1cd5ad0ca3c4702b2159cf76f
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\1b
# ---
# Папок нет
# ---
# Список файлов ['1e9b49d8ee20f294e07d1d96b75a898cc53e29']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\1b\1e9b49d8ee20f294e07d1d96b75a898cc53e29
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\1e
# ---
# Папок нет
# ---
# Список файлов ['3532921211f3b440e8540ced8479e0ca842a30']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\1e\3532921211f3b440e8540ced8479e0ca842a30
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\25
# ---
# Папок нет
# ---
# Список файлов ['dc747d85c3155aab498abd97e67c678260c284']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\25\dc747d85c3155aab498abd97e67c678260c284
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\29
# ---
# Папок нет
# ---
# Список файлов ['45d0fe9cade02678b4ca703a1636a2281742a9']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\29\45d0fe9cade02678b4ca703a1636a2281742a9
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\2b
# ---
# Папок нет
# ---
# Список файлов ['422efe669ea0f40ea872feb7a1befba968a6d8']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\2b\422efe669ea0f40ea872feb7a1befba968a6d8
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\4f
# ---
# Папок нет
# ---
# Список файлов ['32839625e333faacfcafda593c67faef861284']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\4f\32839625e333faacfcafda593c67faef861284
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\52
# ---
# Папок нет
# ---
# Список файлов ['f9d437a36e35a9927e60abefc62f9fd713457d']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\52\f9d437a36e35a9927e60abefc62f9fd713457d
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\5a
# ---
# Папок нет
# ---
# Список файлов ['f1311a22aad436e97879bb92d9068d6ccdecf0']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\5a\f1311a22aad436e97879bb92d9068d6ccdecf0
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\5c
# ---
# Папок нет
# ---
# Список файлов ['b8476ac51c1d360605a1d1baa6393ac5f48fcf']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\5c\b8476ac51c1d360605a1d1baa6393ac5f48fcf
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\61
# ---
# Папок нет
# ---
# Список файлов ['fd1cb152419328161be574474157565281b252']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\61\fd1cb152419328161be574474157565281b252
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\6e
# ---
# Папок нет
# ---
# Список файлов ['968e79410222dba433f24d9973503207c70e61']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\6e\968e79410222dba433f24d9973503207c70e61
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\70
# ---
# Папок нет
# ---
# Список файлов ['f9caf5ad85082b81009977da3c13c9c60d4864']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\70\f9caf5ad85082b81009977da3c13c9c60d4864
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\79
# ---
# Папок нет
# ---
# Список файлов ['ceab2a19c342ddf51002a011c274174e5d09c6']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\79\ceab2a19c342ddf51002a011c274174e5d09c6
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\7a
# ---
# Папок нет
# ---
# Список файлов ['74d3c974c5e6ab06677e2ef8d98c5ed3c91983']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\7a\74d3c974c5e6ab06677e2ef8d98c5ed3c91983
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\7b
# ---
# Папок нет
# ---
# Список файлов ['69004fda65d893e0b7149427240d4289947608']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\7b\69004fda65d893e0b7149427240d4289947608
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\7e
# ---
# Папок нет
# ---
# Список файлов ['3c3d13564006c12232ed7515c527d05e2b2794']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\7e\3c3d13564006c12232ed7515c527d05e2b2794
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\80
# ---
# Папок нет
# ---
# Список файлов ['729d384e6971520aa243fa23d57f8a044ac46e', '8c1e76e13184ea24f6459805f37a6eb8380e3a']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\80\729d384e6971520aa243fa23d57f8a044ac46e
# Файл  g:\Data Sciense\IDE SF\.git\objects\80\8c1e76e13184ea24f6459805f37a6eb8380e3a
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\92
# ---
# Папок нет
# ---
# Список файлов ['ff10a039d0170156ada891da727fde13f90076']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\92\ff10a039d0170156ada891da727fde13f90076
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\9d
# ---
# Папок нет
# ---
# Список файлов ['542114f0f9c38ff9adc4da8ee2838fbdad66e0']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\9d\542114f0f9c38ff9adc4da8ee2838fbdad66e0
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\a1
# ---
# Папок нет
# ---
# Список файлов ['57cbf1d1c2ba1049eb126c30f3fc561dba4017']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\a1\57cbf1d1c2ba1049eb126c30f3fc561dba4017
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\a6
# ---
# Папок нет
# ---
# Список файлов ['bd3c6e06107efbaf1c75ea39839c571826d057']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\a6\bd3c6e06107efbaf1c75ea39839c571826d057
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\b6
# ---
# Папок нет
# ---
# Список файлов ['e47617de110dea7ca47e087ff1347cc2646eda']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\b6\e47617de110dea7ca47e087ff1347cc2646eda
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\b8
# ---
# Папок нет
# ---
# Список файлов ['188e4f4d916a0d88f9978f76f30806ff0775c8']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\b8\188e4f4d916a0d88f9978f76f30806ff0775c8
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\be
# ---
# Папок нет
# ---
# Список файлов ['aa540e2cb57600db73f6b102103239dd3caf97']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\be\aa540e2cb57600db73f6b102103239dd3caf97
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\bf
# ---
# Папок нет
# ---
# Список файлов ['7c8ab3a174d8677ce5a393379b7839c3190ac2']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\bf\7c8ab3a174d8677ce5a393379b7839c3190ac2
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\c0
# ---
# Папок нет
# ---
# Список файлов ['8f79660e7a29ea69d1b966690f55bc7b8a300d']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\c0\8f79660e7a29ea69d1b966690f55bc7b8a300d
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\c1
# ---
# Папок нет
# ---
# Список файлов ['425c20600065244126bd56900a93c678ad5950']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\c1\425c20600065244126bd56900a93c678ad5950
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\c3
# ---
# Папок нет
# ---
# Список файлов ['919c64920d8f1e2793c3884ce0b6924da7b192']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\c3\919c64920d8f1e2793c3884ce0b6924da7b192
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\ca
# ---
# Папок нет
# ---
# Список файлов ['9504f7c7da5c89805238c91224d7c6c464cbe0']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\ca\9504f7c7da5c89805238c91224d7c6c464cbe0
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\d1
# ---
# Папок нет
# ---
# Список файлов ['0301642b52a07a762b698de540490b2eee5f20', '692cee5ba45fade31afff80faf709d391958a3']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\d1\0301642b52a07a762b698de540490b2eee5f20
# Файл  g:\Data Sciense\IDE SF\.git\objects\d1\692cee5ba45fade31afff80faf709d391958a3
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\d6
# ---
# Папок нет
# ---
# Список файлов ['ad6ec20e6a0a79c0a2c7115284f8fb265d19ce']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\d6\ad6ec20e6a0a79c0a2c7115284f8fb265d19ce
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\d8
# ---
# Папок нет
# ---
# Список файлов ['fb4975aa0e46080faaff6eb25cda39e3e17fed']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\d8\fb4975aa0e46080faaff6eb25cda39e3e17fed
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\da
# ---
# Папок нет
# ---
# Список файлов ['98015e125c68712d4516f8a2376b80c80ff3fc', 'c56fc97a6a57465eb8dcfdb43fa94f55be648a']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\da\98015e125c68712d4516f8a2376b80c80ff3fc
# Файл  g:\Data Sciense\IDE SF\.git\objects\da\c56fc97a6a57465eb8dcfdb43fa94f55be648a
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\dd
# ---
# Папок нет
# ---
# Список файлов ['0ddb7be88c0c1df95b17831a3b68f3ea78ae39']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\dd\0ddb7be88c0c1df95b17831a3b68f3ea78ae39
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\e8
# ---
# Папок нет
# ---
# Список файлов ['e5f1ab0a51d62f2e1047abfaf044aad3fe2c63']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\e8\e5f1ab0a51d62f2e1047abfaf044aad3fe2c63
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\ec
# ---
# Папок нет
# ---
# Список файлов ['ea7129b8b591af33d8469699c31c6ddcb966d2']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\ec\ea7129b8b591af33d8469699c31c6ddcb966d2
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\ed
# ---
# Папок нет
# ---
# Список файлов ['0cb724954623e65d7acc18e7238fd1ee93e7bf']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\ed\0cb724954623e65d7acc18e7238fd1ee93e7bf
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\f0
# ---
# Папок нет
# ---
# Список файлов ['4115008aa57e6ac171961d87a9c775586b7a05', 'a8a81793568a324d941749078cb69b637e1cb8']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\f0\4115008aa57e6ac171961d87a9c775586b7a05
# Файл  g:\Data Sciense\IDE SF\.git\objects\f0\a8a81793568a324d941749078cb69b637e1cb8
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\f1
# ---
# Папок нет
# ---
# Список файлов ['dfa40f6fd45ec04d82c66998b9a2f8da4958ef']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\f1\dfa40f6fd45ec04d82c66998b9a2f8da4958ef
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\f2
# ---
# Папок нет
# ---
# Список файлов ['e3902a9c3a91d053c8d267778f6d789bdf6fc0']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\f2\e3902a9c3a91d053c8d267778f6d789bdf6fc0
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\f5
# ---
# Папок нет
# ---
# Список файлов ['0b5d0ffe84f738c846c73a1ce331f48580343c']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\f5\0b5d0ffe84f738c846c73a1ce331f48580343c
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\f7
# ---
# Папок нет
# ---
# Список файлов ['d83c02cd2111a83988290963e36f99ac716dcb']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\f7\d83c02cd2111a83988290963e36f99ac716dcb
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\fa
# ---
# Папок нет
# ---
# Список файлов ['b22f9b69429ac6b7532082a4d594c2df7efb76']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\fa\b22f9b69429ac6b7532082a4d594c2df7efb76
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\fb
# ---
# Папок нет
# ---
# Список файлов ['b167acc2856a45e4497767bf0c00a378be2cba']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\objects\fb\b167acc2856a45e4497767bf0c00a378be2cba
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\info
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\objects\pack
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\refs
# ---
# Список папок ['heads', 'remotes', 'tags']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\IDE SF\.git\refs\heads
# Папка  g:\Data Sciense\IDE SF\.git\refs\remotes
# Папка  g:\Data Sciense\IDE SF\.git\refs\tags
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\refs\heads
# ---
# Папок нет
# ---
# Список файлов ['main', 'master']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\refs\heads\main
# Файл  g:\Data Sciense\IDE SF\.git\refs\heads\master
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\refs\remotes
# ---
# Список папок ['SF_DS_homework']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\IDE SF\.git\refs\remotes\SF_DS_homework
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\refs\remotes\SF_DS_homework
# ---
# Папок нет
# ---
# Список файлов ['main', 'master']
# ---
# Файл  g:\Data Sciense\IDE SF\.git\refs\remotes\SF_DS_homework\main
# Файл  g:\Data Sciense\IDE SF\.git\refs\remotes\SF_DS_homework\master
# ===
# Текущая директория g:\Data Sciense\IDE SF\.git\refs\tags
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория g:\Data Sciense\IDE SF\project_0
# ---
# Папок нет
# ---
# Список файлов ['game.ipynb', 'game.py', 'game_v2.py', 'README.md']
# ---
# Файл  g:\Data Sciense\IDE SF\project_0\game.ipynb
# Файл  g:\Data Sciense\IDE SF\project_0\game.py
# Файл  g:\Data Sciense\IDE SF\project_0\game_v2.py
# Файл  g:\Data Sciense\IDE SF\project_0\README.md
# ===
# Текущая директория g:\Data Sciense\SF практика
# ---
# Список папок ['.git', 'PY-10. Введение в Pandas', 'PY-11. Базовые приемы Pandas', 'PY-12. Продвинутые методы Pandas', 'PY-13. Визуализация данных', 'PY-14. Очистка данных', 'PY-15. ООП']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\SF практика\.git
# Папка  g:\Data Sciense\SF практика\PY-10. Введение в Pandas
# Папка  g:\Data Sciense\SF практика\PY-11. Базовые приемы Pandas
# Папка  g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas
# Папка  g:\Data Sciense\SF практика\PY-13. Визуализация данных
# Папка  g:\Data Sciense\SF практика\PY-14. Очистка данных
# Папка  g:\Data Sciense\SF практика\PY-15. ООП
# ===
# Текущая директория g:\Data Sciense\SF практика\.git
# ---
# Список папок ['hooks', 'info', 'logs', 'objects', 'refs']
# ---
# Список файлов ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'ORIG_HEAD']
# ---
# Все пути:
# Файл  g:\Data Sciense\SF практика\.git\COMMIT_EDITMSG
# Файл  g:\Data Sciense\SF практика\.git\config
# Файл  g:\Data Sciense\SF практика\.git\description
# Файл  g:\Data Sciense\SF практика\.git\FETCH_HEAD
# Файл  g:\Data Sciense\SF практика\.git\HEAD
# Файл  g:\Data Sciense\SF практика\.git\index
# Файл  g:\Data Sciense\SF практика\.git\ORIG_HEAD
# Папка  g:\Data Sciense\SF практика\.git\hooks
# Папка  g:\Data Sciense\SF практика\.git\info
# Папка  g:\Data Sciense\SF практика\.git\logs
# Папка  g:\Data Sciense\SF практика\.git\objects
# Папка  g:\Data Sciense\SF практика\.git\refs
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\hooks
# ---
# Папок нет
# ---
# Список файлов ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'update.sample']
# ---
# Файл  g:\Data Sciense\SF практика\.git\hooks\applypatch-msg.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\commit-msg.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\fsmonitor-watchman.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\post-update.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\pre-applypatch.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\pre-commit.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\pre-merge-commit.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\pre-push.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\pre-rebase.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\pre-receive.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\prepare-commit-msg.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\push-to-checkout.sample
# Файл  g:\Data Sciense\SF практика\.git\hooks\update.sample
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\info
# ---
# Папок нет
# ---
# Список файлов ['exclude']
# ---
# Файл  g:\Data Sciense\SF практика\.git\info\exclude
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\logs
# ---
# Список папок ['refs']
# ---
# Список файлов ['HEAD']
# ---
# Все пути:
# Файл  g:\Data Sciense\SF практика\.git\logs\HEAD
# Папка  g:\Data Sciense\SF практика\.git\logs\refs
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\logs\refs
# ---
# Список папок ['heads', 'remotes']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\SF практика\.git\logs\refs\heads
# Папка  g:\Data Sciense\SF практика\.git\logs\refs\remotes
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\logs\refs\heads
# ---
# Папок нет
# ---
# Список файлов ['master']
# ---
# Файл  g:\Data Sciense\SF практика\.git\logs\refs\heads\master
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\logs\refs\remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\SF практика\.git\logs\refs\remotes\origin
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\logs\refs\remotes\origin
# ---
# Папок нет
# ---
# Список файлов ['master']
# ---
# Файл  g:\Data Sciense\SF практика\.git\logs\refs\remotes\origin\master
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects
# ---
# Список папок ['00', '07', '0a', '17', '1c', '24', '27', '2c', '2e', '32', '3b', '3d', '47', '49', '4c', '4f', '52', '55', '5a', '5b', '65', '67', '6b', '71', '7a', '83', '91', 'a3', 'a9', 'af', 'b2', 'b7', 'ba', 'bc', 'be', 'ce', 'd2', 'd6', 'd9', 'db', 'e4', 'e6', 'f1', 'fd', 'info', 'pack']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\SF практика\.git\objects\00
# Папка  g:\Data Sciense\SF практика\.git\objects\07
# Папка  g:\Data Sciense\SF практика\.git\objects\0a
# Папка  g:\Data Sciense\SF практика\.git\objects\17
# Папка  g:\Data Sciense\SF практика\.git\objects\1c
# Папка  g:\Data Sciense\SF практика\.git\objects\24
# Папка  g:\Data Sciense\SF практика\.git\objects\27
# Папка  g:\Data Sciense\SF практика\.git\objects\2c
# Папка  g:\Data Sciense\SF практика\.git\objects\2e
# Папка  g:\Data Sciense\SF практика\.git\objects\32
# Папка  g:\Data Sciense\SF практика\.git\objects\3b
# Папка  g:\Data Sciense\SF практика\.git\objects\3d
# Папка  g:\Data Sciense\SF практика\.git\objects\47
# Папка  g:\Data Sciense\SF практика\.git\objects\49
# Папка  g:\Data Sciense\SF практика\.git\objects\4c
# Папка  g:\Data Sciense\SF практика\.git\objects\4f
# Папка  g:\Data Sciense\SF практика\.git\objects\52
# Папка  g:\Data Sciense\SF практика\.git\objects\55
# Папка  g:\Data Sciense\SF практика\.git\objects\5a
# Папка  g:\Data Sciense\SF практика\.git\objects\5b
# Папка  g:\Data Sciense\SF практика\.git\objects\65
# Папка  g:\Data Sciense\SF практика\.git\objects\67
# Папка  g:\Data Sciense\SF практика\.git\objects\6b
# Папка  g:\Data Sciense\SF практика\.git\objects\71
# Папка  g:\Data Sciense\SF практика\.git\objects\7a
# Папка  g:\Data Sciense\SF практика\.git\objects\83
# Папка  g:\Data Sciense\SF практика\.git\objects\91
# Папка  g:\Data Sciense\SF практика\.git\objects\a3
# Папка  g:\Data Sciense\SF практика\.git\objects\a9
# Папка  g:\Data Sciense\SF практика\.git\objects\af
# Папка  g:\Data Sciense\SF практика\.git\objects\b2
# Папка  g:\Data Sciense\SF практика\.git\objects\b7
# Папка  g:\Data Sciense\SF практика\.git\objects\ba
# Папка  g:\Data Sciense\SF практика\.git\objects\bc
# Папка  g:\Data Sciense\SF практика\.git\objects\be
# Папка  g:\Data Sciense\SF практика\.git\objects\ce
# Папка  g:\Data Sciense\SF практика\.git\objects\d2
# Папка  g:\Data Sciense\SF практика\.git\objects\d6
# Папка  g:\Data Sciense\SF практика\.git\objects\d9
# Папка  g:\Data Sciense\SF практика\.git\objects\db
# Папка  g:\Data Sciense\SF практика\.git\objects\e4
# Папка  g:\Data Sciense\SF практика\.git\objects\e6
# Папка  g:\Data Sciense\SF практика\.git\objects\f1
# Папка  g:\Data Sciense\SF практика\.git\objects\fd
# Папка  g:\Data Sciense\SF практика\.git\objects\info
# Папка  g:\Data Sciense\SF практика\.git\objects\pack
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\00
# ---
# Папок нет
# ---
# Список файлов ['cfc7f498f43541e0182ce1d48afce910e50eea']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\00\cfc7f498f43541e0182ce1d48afce910e50eea
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\07
# ---
# Папок нет
# ---
# Список файлов ['166afa39242e9b40998c0d04e67b9711d8d883']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\07\166afa39242e9b40998c0d04e67b9711d8d883
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\0a
# ---
# Папок нет
# ---
# Список файлов ['3167fb978ce75b17fdde90464b8b21d490351c']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\0a\3167fb978ce75b17fdde90464b8b21d490351c
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\17
# ---
# Папок нет
# ---
# Список файлов ['c13c08986355c74689876e77a30a84a8701c94']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\17\c13c08986355c74689876e77a30a84a8701c94
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\1c
# ---
# Папок нет
# ---
# Список файлов ['22bc28468de3100e39bfeb5a93e03312bfea84']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\1c\22bc28468de3100e39bfeb5a93e03312bfea84
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\24
# ---
# Папок нет
# ---
# Список файлов ['1927a595a187aa7bebea003b9b77cc77ee972f']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\24\1927a595a187aa7bebea003b9b77cc77ee972f
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\27
# ---
# Папок нет
# ---
# Список файлов ['c6744ada7ce70b0bf72221de27f7a78566bc69']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\27\c6744ada7ce70b0bf72221de27f7a78566bc69
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\2c
# ---
# Папок нет
# ---
# Список файлов ['1b2e74fe24d0fc851aa9745702fcd7777f690a']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\2c\1b2e74fe24d0fc851aa9745702fcd7777f690a
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\2e
# ---
# Папок нет
# ---
# Список файлов ['84d78491f023d470d3a79041dab4ee3ab22fbb']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\2e\84d78491f023d470d3a79041dab4ee3ab22fbb
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\32
# ---
# Папок нет
# ---
# Список файлов ['65f3ba1747bccb4a9ac00b6ddc895014126bfc']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\32\65f3ba1747bccb4a9ac00b6ddc895014126bfc
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\3b
# ---
# Папок нет
# ---
# Список файлов ['fad7408ec185b2bd88612d195f8cda6734ec1e']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\3b\fad7408ec185b2bd88612d195f8cda6734ec1e
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\3d
# ---
# Папок нет
# ---
# Список файлов ['c5d7a5f8e9abb84a35d9152f1433923fa6809f']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\3d\c5d7a5f8e9abb84a35d9152f1433923fa6809f
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\47
# ---
# Папок нет
# ---
# Список файлов ['4a1260cf348ed96cbf14b63d79c799b8d5217d']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\47\4a1260cf348ed96cbf14b63d79c799b8d5217d
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\49
# ---
# Папок нет
# ---
# Список файлов ['9890aa4bccd8e2b026df78d286b2b2df596896', 'a5336649a23a8e45b7ed5f145935dcbcca8cbd']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\49\9890aa4bccd8e2b026df78d286b2b2df596896
# Файл  g:\Data Sciense\SF практика\.git\objects\49\a5336649a23a8e45b7ed5f145935dcbcca8cbd
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\4c
# ---
# Папок нет
# ---
# Список файлов ['3e666a75a6ead54706a25c62480717ecf8fa8c']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\4c\3e666a75a6ead54706a25c62480717ecf8fa8c
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\4f
# ---
# Папок нет
# ---
# Список файлов ['8da66fb8eacca6a837d3aa970f2d47e016089b', 'e706363c9a4502bc267410779be4b1ca0bfcf1']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\4f\8da66fb8eacca6a837d3aa970f2d47e016089b
# Файл  g:\Data Sciense\SF практика\.git\objects\4f\e706363c9a4502bc267410779be4b1ca0bfcf1
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\52
# ---
# Папок нет
# ---
# Список файлов ['bfa9d6df672ee2d72ce0806eb97738371d24b2']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\52\bfa9d6df672ee2d72ce0806eb97738371d24b2
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\55
# ---
# Папок нет
# ---
# Список файлов ['56700b7fce8234abe74cdeba8b21c406ff4ec4']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\55\56700b7fce8234abe74cdeba8b21c406ff4ec4
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\5a
# ---
# Папок нет
# ---
# Список файлов ['b73a0b61e5edd7f9921900d68070783ba8544d']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\5a\b73a0b61e5edd7f9921900d68070783ba8544d
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\5b
# ---
# Папок нет
# ---
# Список файлов ['c81133bf7375b64440be218d2e29502bf8498a']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\5b\c81133bf7375b64440be218d2e29502bf8498a
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\65
# ---
# Папок нет
# ---
# Список файлов ['aa1d502f62beda17b99d937b21008131071e1e']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\65\aa1d502f62beda17b99d937b21008131071e1e
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\67
# ---
# Папок нет
# ---
# Список файлов ['dc91f6e0f1ef13f97ed4396013b5253fc524e1']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\67\dc91f6e0f1ef13f97ed4396013b5253fc524e1
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\6b
# ---
# Папок нет
# ---
# Список файлов ['4c28ba03b4fbf67a7633ff05d9442d8e51bcdf']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\6b\4c28ba03b4fbf67a7633ff05d9442d8e51bcdf
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\71
# ---
# Папок нет
# ---
# Список файлов ['8a76f35bcb8c177ba5b2510c379f52636c40ec']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\71\8a76f35bcb8c177ba5b2510c379f52636c40ec
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\7a
# ---
# Папок нет
# ---
# Список файлов ['857b1e2b0f0d3d11994c563220d87d7180fdde']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\7a\857b1e2b0f0d3d11994c563220d87d7180fdde
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\83
# ---
# Папок нет
# ---
# Список файлов ['ea2bd6a9663d8c23471e061fd2b65dd924e9e2']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\83\ea2bd6a9663d8c23471e061fd2b65dd924e9e2
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\91
# ---
# Папок нет
# ---
# Список файлов ['0d4c4330d375775343cfe201a2b4208c7634c8']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\91\0d4c4330d375775343cfe201a2b4208c7634c8
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\a3
# ---
# Папок нет
# ---
# Список файлов ['66e8a58c1a1d99f63754fd2f1ebf693ad41c97']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\a3\66e8a58c1a1d99f63754fd2f1ebf693ad41c97
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\a9
# ---
# Папок нет
# ---
# Список файлов ['bf1f61b52daa3f79f4c2469187119854e3b8b6']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\a9\bf1f61b52daa3f79f4c2469187119854e3b8b6
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\af
# ---
# Папок нет
# ---
# Список файлов ['2287a6b9784a4f0d284e778c2b5624bea36782']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\af\2287a6b9784a4f0d284e778c2b5624bea36782
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\b2
# ---
# Папок нет
# ---
# Список файлов ['b851e5463c797abf34a59490a5afac0f39e7f7']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\b2\b851e5463c797abf34a59490a5afac0f39e7f7
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\b7
# ---
# Папок нет
# ---
# Список файлов ['2d43f377f371af6cb70193d84a9404a9aebd5b']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\b7\2d43f377f371af6cb70193d84a9404a9aebd5b
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\ba
# ---
# Папок нет
# ---
# Список файлов ['45445a73956380de2143a296555cc668cb0a79']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\ba\45445a73956380de2143a296555cc668cb0a79
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\bc
# ---
# Папок нет
# ---
# Список файлов ['e7c936e3e9d3b7f6f80413ef8a414e76c15d4a']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\bc\e7c936e3e9d3b7f6f80413ef8a414e76c15d4a
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\be
# ---
# Папок нет
# ---
# Список файлов ['16fd689ea3644a70a2a735bbeed7f14f492e7a']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\be\16fd689ea3644a70a2a735bbeed7f14f492e7a
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\ce
# ---
# Папок нет
# ---
# Список файлов ['ebdf49edc520c79a66e91d9e3841e434dc359d']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\ce\ebdf49edc520c79a66e91d9e3841e434dc359d
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\d2
# ---
# Папок нет
# ---
# Список файлов ['2334eaa5347895308492a807207a3fcb09f228', '6342f222e2ce9af8b89f4cbefc06d1fc880e3e']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\d2\2334eaa5347895308492a807207a3fcb09f228
# Файл  g:\Data Sciense\SF практика\.git\objects\d2\6342f222e2ce9af8b89f4cbefc06d1fc880e3e
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\d6
# ---
# Папок нет
# ---
# Список файлов ['db744e75a250d89e53bff2761daa4abf3b4390']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\d6\db744e75a250d89e53bff2761daa4abf3b4390
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\d9
# ---
# Папок нет
# ---
# Список файлов ['402d4bebfc2d595f727e830fc6a674723c410d']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\d9\402d4bebfc2d595f727e830fc6a674723c410d
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\db
# ---
# Папок нет
# ---
# Список файлов ['ad8b74c720ad6c23244219e594885a8a959e59']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\db\ad8b74c720ad6c23244219e594885a8a959e59
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\e4
# ---
# Папок нет
# ---
# Список файлов ['306dffc73b96f5d39ac0979ff72dccfb8b2b2b']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\e4\306dffc73b96f5d39ac0979ff72dccfb8b2b2b
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\e6
# ---
# Папок нет
# ---
# Список файлов ['9de29bb2d1d6434b8b29ae775ad8c2e48c5391']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\e6\9de29bb2d1d6434b8b29ae775ad8c2e48c5391
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\f1
# ---
# Папок нет
# ---
# Список файлов ['d8e3f37cd24b619df9ea69ea1c5a9559ddc8a4']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\f1\d8e3f37cd24b619df9ea69ea1c5a9559ddc8a4
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\fd
# ---
# Папок нет
# ---
# Список файлов ['8456f1f263ad1495cf4bd664cb33f2d93de600']
# ---
# Файл  g:\Data Sciense\SF практика\.git\objects\fd\8456f1f263ad1495cf4bd664cb33f2d93de600
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\info
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\objects\pack
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\refs
# ---
# Список папок ['heads', 'remotes', 'tags']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\SF практика\.git\refs\heads
# Папка  g:\Data Sciense\SF практика\.git\refs\remotes
# Папка  g:\Data Sciense\SF практика\.git\refs\tags
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\refs\heads
# ---
# Папок нет
# ---
# Список файлов ['master']
# ---
# Файл  g:\Data Sciense\SF практика\.git\refs\heads\master
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\refs\remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\SF практика\.git\refs\remotes\origin
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\refs\remotes\origin
# ---
# Папок нет
# ---
# Список файлов ['master']
# ---
# Файл  g:\Data Sciense\SF практика\.git\refs\remotes\origin\master
# ===
# Текущая директория g:\Data Sciense\SF практика\.git\refs\tags
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория g:\Data Sciense\SF практика\PY-10. Введение в Pandas
# ---
# Список папок ['data']
# ---
# Список файлов ['DS-2.4.ipynb', 'DS-3.5.ipynb', 'DS-9.ipynb', 'Введение в Pandas.ipynb']
# ---
# Все пути:
# Файл  g:\Data Sciense\SF практика\PY-10. Введение в Pandas\DS-2.4.ipynb
# Файл  g:\Data Sciense\SF практика\PY-10. Введение в Pandas\DS-3.5.ipynb
# Файл  g:\Data Sciense\SF практика\PY-10. Введение в Pandas\DS-9.ipynb
# Файл  g:\Data Sciense\SF практика\PY-10. Введение в Pandas\Введение в Pandas.ipynb
# Папка  g:\Data Sciense\SF практика\PY-10. Введение в Pandas\data
# ===
# Текущая директория g:\Data Sciense\SF практика\PY-10. Введение в Pandas\data
# ---
# Папок нет
# ---
# Список файлов ['countries.csv', 'melb_data.csv', 'students_performance.csv']
# ---
# Файл  g:\Data Sciense\SF практика\PY-10. Введение в Pandas\data\countries.csv
# Файл  g:\Data Sciense\SF практика\PY-10. Введение в Pandas\data\melb_data.csv
# Файл  g:\Data Sciense\SF практика\PY-10. Введение в Pandas\data\students_performance.csv
# ===
# Текущая директория g:\Data Sciense\SF практика\PY-11. Базовые приемы Pandas
# ---
# Список папок ['data']
# ---
# Список файлов ['DS-1.ipynb', 'DS-3.4 and 3.5.ipynb', 'DS-6.ipynb']
# ---
# Все пути:
# Файл  g:\Data Sciense\SF практика\PY-11. Базовые приемы Pandas\DS-1.ipynb
# Файл  g:\Data Sciense\SF практика\PY-11. Базовые приемы Pandas\DS-3.4 and 3.5.ipynb
# Файл  g:\Data Sciense\SF практика\PY-11. Базовые приемы Pandas\DS-6.ipynb
# Папка  g:\Data Sciense\SF практика\PY-11. Базовые приемы Pandas\data
# ===
# Текущая директория g:\Data Sciense\SF практика\PY-11. Базовые приемы Pandas\data
# ---
# Папок нет
# ---
# Список файлов ['citibike-tripdata.csv', 'melb_data_ps.csv']
# ---
# Файл  g:\Data Sciense\SF практика\PY-11. Базовые приемы Pandas\data\citibike-tripdata.csv
# Файл  g:\Data Sciense\SF практика\PY-11. Базовые приемы Pandas\data\melb_data_ps.csv
# ===
# Текущая директория g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas
# ---
# Список папок ['data']
# ---
# Список файлов ['Продвинутые методы.ipynb']
# ---
# Все пути:
# Файл  g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas\Продвинутые методы.ipynb
# Папка  g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas\data
# ===
# Текущая директория g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas\data
# ---
# Папок нет
# ---
# Список файлов ['dates.csv', 'melb_data_fe.csv', 'movies.csv', 'orders.csv', 'products.csv', 'ratings1.csv', 'ratings2.csv']
# ---
# Файл  g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas\data\dates.csv
# Файл  g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas\data\melb_data_fe.csv
# Файл  g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas\data\movies.csv
# Файл  g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas\data\orders.csv
# Файл  g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas\data\products.csv
# Файл  g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas\data\ratings1.csv
# Файл  g:\Data Sciense\SF практика\PY-12. Продвинутые методы Pandas\data\ratings2.csv
# ===
# Текущая директория g:\Data Sciense\SF практика\PY-13. Визуализация данных
# ---
# Список папок ['data']
# ---
# Список файлов ['PY-13. Визуализация данных.ipynb', 'PY-13. Практика.ipynb', 'Types_of_visualization.ipynb', 'Visualization_Pandas.ipynb']
# ---
# Все пути:
# Файл  g:\Data Sciense\SF практика\PY-13. Визуализация данных\PY-13. Визуализация данных.ipynb
# Файл  g:\Data Sciense\SF практика\PY-13. Визуализация данных\PY-13. Практика.ipynb
# Файл  g:\Data Sciense\SF практика\PY-13. Визуализация данных\Types_of_visualization.ipynb
# Файл  g:\Data Sciense\SF практика\PY-13. Визуализация данных\Visualization_Pandas.ipynb
# Папка  g:\Data Sciense\SF практика\PY-13. Визуализация данных\data
# ===
# Текущая директория g:\Data Sciense\SF практика\PY-13. Визуализация данных\data
# ---
# Папок нет
# ---
# Список файлов ['churn.csv', 'country_vaccinations.csv', 'covid_data.csv', 'melb_data.csv', 'vgsales.csv']
# ---
# Файл  g:\Data Sciense\SF практика\PY-13. Визуализация данных\data\churn.csv
# Файл  g:\Data Sciense\SF практика\PY-13. Визуализация данных\data\country_vaccinations.csv
# Файл  g:\Data Sciense\SF практика\PY-13. Визуализация данных\data\covid_data.csv
# Файл  g:\Data Sciense\SF практика\PY-13. Визуализация данных\data\melb_data.csv
# Файл  g:\Data Sciense\SF практика\PY-13. Визуализация данных\data\vgsales.csv
# ===
# Текущая директория g:\Data Sciense\SF практика\PY-14. Очистка данных
# ---
# Список папок ['data']
# ---
# Список файлов ['PY-14. Очистка данных.ipynb', 'PY-14. Практика.ipynb']
# ---
# Все пути:
# Файл  g:\Data Sciense\SF практика\PY-14. Очистка данных\PY-14. Очистка данных.ipynb
# Файл  g:\Data Sciense\SF практика\PY-14. Очистка данных\PY-14. Практика.ipynb
# Папка  g:\Data Sciense\SF практика\PY-14. Очистка данных\data
# ===
# Текущая директория g:\Data Sciense\SF практика\PY-14. Очистка данных\data
# ---
# Папок нет
# ---
# Список файлов ['diabetes_data.csv', 'sber_data.csv']
# ---
# Файл  g:\Data Sciense\SF практика\PY-14. Очистка данных\data\diabetes_data.csv
# Файл  g:\Data Sciense\SF практика\PY-14. Очистка данных\data\sber_data.csv
# ===
# Текущая директория g:\Data Sciense\SF практика\PY-15. ООП
# ---
# Папок нет
# ---
# Список файлов ['PY-15. ООП.ipynb']
# ---
# Файл  g:\Data Sciense\SF практика\PY-15. ООП\PY-15. ООП.ipynb
# ===
# Текущая директория g:\Data Sciense\temp
# ---
# Список папок ['Mars habr', 'PY-10. Введение в Pandas', 'PY-11. Базовые приемы Pandas', 'PY-12. Продвинутые методы Pandas', 'PY-13. Визуализация данных', 'PY-14. Очистка данных']
# ---
# Файлов нет
# ---
# Папка  g:\Data Sciense\temp\Mars habr
# Папка  g:\Data Sciense\temp\PY-10. Введение в Pandas
# Папка  g:\Data Sciense\temp\PY-11. Базовые приемы Pandas
# Папка  g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas
# Папка  g:\Data Sciense\temp\PY-13. Визуализация данных
# Папка  g:\Data Sciense\temp\PY-14. Очистка данных
# ===
# Текущая директория g:\Data Sciense\temp\Mars habr
# ---
# Папок нет
# ---
# Список файлов ['mars.ipynb', 'Mars_MGS_MOLA_Shade_global_463m.tif']
# ---
# Файл  g:\Data Sciense\temp\Mars habr\mars.ipynb
# Файл  g:\Data Sciense\temp\Mars habr\Mars_MGS_MOLA_Shade_global_463m.tif
# ===
# Текущая директория g:\Data Sciense\temp\PY-10. Введение в Pandas
# ---
# Список папок ['data']
# ---
# Список файлов ['DS-2.4.ipynb', 'DS-3.5.ipynb', 'DS-9.ipynb', 'Введение в Pandas.ipynb']
# ---
# Все пути:
# Файл  g:\Data Sciense\temp\PY-10. Введение в Pandas\DS-2.4.ipynb
# Файл  g:\Data Sciense\temp\PY-10. Введение в Pandas\DS-3.5.ipynb
# Файл  g:\Data Sciense\temp\PY-10. Введение в Pandas\DS-9.ipynb
# Файл  g:\Data Sciense\temp\PY-10. Введение в Pandas\Введение в Pandas.ipynb
# Папка  g:\Data Sciense\temp\PY-10. Введение в Pandas\data
# ===
# Текущая директория g:\Data Sciense\temp\PY-10. Введение в Pandas\data
# ---
# Папок нет
# ---
# Список файлов ['countries.csv', 'melb_data.csv', 'students_performance.csv']
# ---
# Файл  g:\Data Sciense\temp\PY-10. Введение в Pandas\data\countries.csv
# Файл  g:\Data Sciense\temp\PY-10. Введение в Pandas\data\melb_data.csv
# Файл  g:\Data Sciense\temp\PY-10. Введение в Pandas\data\students_performance.csv
# ===
# Текущая директория g:\Data Sciense\temp\PY-11. Базовые приемы Pandas
# ---
# Список папок ['data']
# ---
# Список файлов ['DS-1.ipynb', 'DS-3.4 and 3.5.ipynb', 'DS-6.ipynb']
# ---
# Все пути:
# Файл  g:\Data Sciense\temp\PY-11. Базовые приемы Pandas\DS-1.ipynb
# Файл  g:\Data Sciense\temp\PY-11. Базовые приемы Pandas\DS-3.4 and 3.5.ipynb
# Файл  g:\Data Sciense\temp\PY-11. Базовые приемы Pandas\DS-6.ipynb
# Папка  g:\Data Sciense\temp\PY-11. Базовые приемы Pandas\data
# ===
# Текущая директория g:\Data Sciense\temp\PY-11. Базовые приемы Pandas\data
# ---
# Папок нет
# ---
# Список файлов ['citibike-tripdata.csv', 'melb_data_ps.csv']
# ---
# Файл  g:\Data Sciense\temp\PY-11. Базовые приемы Pandas\data\citibike-tripdata.csv
# Файл  g:\Data Sciense\temp\PY-11. Базовые приемы Pandas\data\melb_data_ps.csv
# ===
# Текущая директория g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas
# ---
# Список папок ['data']
# ---
# Список файлов ['Продвинутые методы.ipynb']
# ---
# Все пути:
# Файл  g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas\Продвинутые методы.ipynb
# Папка  g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas\data
# ===
# Текущая директория g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas\data
# ---
# Папок нет
# ---
# Список файлов ['dates.csv', 'melb_data_fe.csv', 'movies.csv', 'orders.csv', 'products.csv', 'ratings1.csv', 'ratings2.csv']
# ---
# Файл  g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas\data\dates.csv
# Файл  g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas\data\melb_data_fe.csv
# Файл  g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas\data\movies.csv
# Файл  g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas\data\orders.csv
# Файл  g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas\data\products.csv
# Файл  g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas\data\ratings1.csv
# Файл  g:\Data Sciense\temp\PY-12. Продвинутые методы Pandas\data\ratings2.csv
# ===
# Текущая директория g:\Data Sciense\temp\PY-13. Визуализация данных
# ---
# Список папок ['data']
# ---
# Список файлов ['PY-13. Визуализация данных.ipynb', 'PY-13. Практика.ipynb', 'Types_of_visualization.ipynb', 'Visualization_Pandas.ipynb']
# ---
# Все пути:
# Файл  g:\Data Sciense\temp\PY-13. Визуализация данных\PY-13. Визуализация данных.ipynb
# Файл  g:\Data Sciense\temp\PY-13. Визуализация данных\PY-13. Практика.ipynb
# Файл  g:\Data Sciense\temp\PY-13. Визуализация данных\Types_of_visualization.ipynb
# Файл  g:\Data Sciense\temp\PY-13. Визуализация данных\Visualization_Pandas.ipynb
# Папка  g:\Data Sciense\temp\PY-13. Визуализация данных\data
# ===
# Текущая директория g:\Data Sciense\temp\PY-13. Визуализация данных\data
# ---
# Папок нет
# ---
# Список файлов ['churn.csv', 'country_vaccinations.csv', 'covid_data.csv', 'melb_data.csv', 'vgsales.csv']
# ---
# Файл  g:\Data Sciense\temp\PY-13. Визуализация данных\data\churn.csv
# Файл  g:\Data Sciense\temp\PY-13. Визуализация данных\data\country_vaccinations.csv
# Файл  g:\Data Sciense\temp\PY-13. Визуализация данных\data\covid_data.csv
# Файл  g:\Data Sciense\temp\PY-13. Визуализация данных\data\melb_data.csv
# Файл  g:\Data Sciense\temp\PY-13. Визуализация данных\data\vgsales.csv
# ===
# Текущая директория g:\Data Sciense\temp\PY-14. Очистка данных
# ---
# Список папок ['data']
# ---
# Список файлов ['PY-14. Очистка данных.ipynb', 'PY-14. Практика.ipynb']
# ---
# Все пути:
# Файл  g:\Data Sciense\temp\PY-14. Очистка данных\PY-14. Очистка данных.ipynb
# Файл  g:\Data Sciense\temp\PY-14. Очистка данных\PY-14. Практика.ipynb
# Папка  g:\Data Sciense\temp\PY-14. Очистка данных\data
# ===
# Текущая директория g:\Data Sciense\temp\PY-14. Очистка данных\data
# ---
# Папок нет
# ---
# Список файлов ['diabetes_data.csv', 'sber_data.csv']
# ---
# Файл  g:\Data Sciense\temp\PY-14. Очистка данных\data\diabetes_data.csv
# Файл  g:\Data Sciense\temp\PY-14. Очистка данных\data\sber_data.csv
# ===
