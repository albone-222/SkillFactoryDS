# %%
import requests 
url = 'https://www.cbr-xml-daily.ru/daily_json.js'
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# {
#     "Date": "2022-06-02T11:30:00+03:00",
#     "PreviousDate": "2022-06-01T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2022\/06\/01\/daily_json.js",
#     "Timestamp": "2022-06-01T20:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 44.0641,
#             "Previous": 44.2769
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 36.1608,
#             "Previous": 36.2394
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
# ...

# %%
from pprint import pprint 
currencies = response.json() 
pprint(currencies)
# Out:
# {'Date': '2022-06-02T11:30:00+03:00',
#  'PreviousDate': '2022-06-01T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2022/06/01/daily_json.js',
#  'Timestamp': '2022-06-01T20:00:00+03:00',
#  'Valute': {'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 13.7518,
#                     'Value': 13.7944},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 44.2769,
#                     'Value': 44.0641},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
# ...

# %%
pprint(currencies['Valute']['EUR'])
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 62.7397,
#  'Value': 63.6629}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %%
from bs4 import BeautifulSoup
def wiki_header(link):
    response = requests.get(link)
    page = BeautifulSoup(response.text, 'html.parser')
    return page.find('h1').text

print(wiki_header('https://en.wikipedia.org/wiki/Operating_system'))
# Out:
# Operating system

# %%
token = '79dc43f279dc43f279dc43f20779a09f50779dc79dc43f21b4b84096ae9e834953f86d9' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
ids = ",".join(map(str, range(1, 501)))
params = {'user_id': ids, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params).json() # Отправляем запрос
#pprint(response)
count_woman = 0
count_man = 0

for user in response['response']:
    #pprint(user)
    if user['sex'] == 1:
        count_woman += 1
    if user['sex'] == 2:
        count_man += 1

print(round(count_woman/(count_woman + count_man), 2))
# Out:
# 0.49

# %%
def apply_discounts(products, stocks):
    """
    Напишите функцию apply_discounts(), которая снижает цену продуктов в словаре products на указанный в словаре stocks процент. 
    Функция должна вернуть результирующий словарь, ключи которого — товары, а значения — новые цены.
    Если продукта из словаря stocks нет в словаре products, то его необходимо пропустить. Цены округлите до второго знака после запятой.
    """
    for product in stocks:
        if product in products.keys():
            discount = int(stocks[product].replace('%', ''))
            products[product] = round(products[product] * (100 - discount) / 100, 2)
    return products
    
if __name__ == '__main__':
    products={
        "Oranges (packaged)": 114.99, 
        "Candy (Rotfront)": 280.00,
        "Boiled sausage": 199.99,
        "Juice J7 (orange)": 119.99,
        "Trout (Seven Seas)": 399.99
        }
    stocks = {
        "Boiled sausage": "33%",
        "Juice J7 (orange)": "12%",
        "Trout (Seven Seas)": "18%"
    }
    new_products = apply_discounts(products, stocks)
    print(new_products)
# Out:
# {'Oranges (packaged)': 114.99, 'Candy (Rotfront)': 280.0, 'Boiled sausage': 133.99, 'Juice J7 (orange)': 105.59, 'Trout (Seven Seas)': 327.99}

# %%
import pandas as pd
df_bronze = pd.read_csv('bronze_top.csv')
df_silver = pd.read_csv('silver_top.csv')

# %%
df_bronze.head()
# Out:
#           Country   Total
# 0   United States  1052.0
# 1    Soviet Union   584.0
# 2  United Kingdom   505.0
# 3          France   475.0
# 4         Germany   454.0

# %%
df_silver.head()
# Out:
#           Country   Total
# 0   United States  1195.0
# 1    Soviet Union   627.0
# 2  United Kingdom   591.0
# 3          France   461.0
# 4           Italy   394.0

# %%
merged = df_silver.merge(df_bronze, how='inner', on='Country', suffixes=('_silver', '_bronze'))
merged.head()
# Out:
#           Country  Total_silver  Total_bronze
# 0   United States        1195.0        1052.0
# 1    Soviet Union         627.0         584.0
# 2  United Kingdom         591.0         505.0
# 3          France         461.0         475.0
